# %% [markdown]
# # Распознавание объектов на изображениях из набора данных CIFAR-10

# %%
import numpy as np
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras import utils
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt
import os

# %%
# Названия классов из набора данных CIFAR-10
classes=['самолет', 'автомобиль', 'птица', 'кот', 'олень', 'собака', 'лягушка', 'лошадь', 'корабль', 'грузовик']

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# **Загружаем данные**

# %%
(X_train, Y_train), (X_test, Y_test) = cifar10.load_data()

# %% [markdown]
# **Просмотр примеров данных**

# %%
plt.figure(figsize=(10,10))
for i in range(100,150):
    plt.subplot(5,10,i-100+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(X_train[i])
    plt.xlabel(classes[Y_train[i][0]])

# %% [markdown]
# **Нормализуем данные**

# %%
x_train = X_train / 255
x_test = X_test / 255

# %% [markdown]
# **Преобразуем правильные ответы в формат one hot encoding**

# %%
y_train = utils.to_categorical(Y_train, 10)
y_test = utils.to_categorical(Y_test, 10)

# %% [markdown]
# ## Создаем нейронную сеть

# %%
# Создаем последовательную модель
model = Sequential()
# Первый сверточный слой
model.add(Conv2D(32, (3, 3), padding='same',
                        input_shape=(32, 32, 3), activation='relu'))
# Второй сверточный слой
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
# Первый слой подвыборки
model.add(MaxPooling2D(pool_size=(2, 2)))
# Слой регуляризации Dropout
model.add(Dropout(0.25))

# Третий сверточный слой
model.add(Conv2D(64, (3, 3), activation='relu'))
# Четвертый сверточный слой
model.add(Conv2D(64, (3, 3), activation='relu'))
# Второй слой подвыборки
model.add(MaxPooling2D(pool_size=(2, 2)))
# Слой регуляризации Dropout
model.add(Dropout(0.25))

# Слой преобразования данных из 2D представления в плоское
model.add(Flatten())
# Полносвязный слой для классификации
model.add(Dense(512, activation='relu'))
# Слой регуляризации Dropout
model.add(Dropout(0.5))
# Выходной полносвязный слой
model.add(Dense(10, activation='softmax'))

# %% [markdown]
# **Печатаем информацию о сети**

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 32)        9248
#
#  max_pooling2d (MaxPooling2  (None, 16, 16, 32)        0
#  D)
#
#  dropout (Dropout)           (None, 16, 16, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 14, 14, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 12, 12, 64)        36928
#
#  max_pooling2d_1 (MaxPoolin  (None, 6, 6, 64)          0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 6, 6, 64)          0
#
#  flatten (Flatten)           (None, 2304)              0
#
#  dense (Dense)               (None, 512)               1180160
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 1250858 (4.77 MB)
# Trainable params: 1250858 (4.77 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# **Компилируем модель**

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %% [markdown]
# ## Обучаем нейронную сеть

# %%
history = model.fit(x_train, y_train,
              batch_size=128,
              epochs=25,
              validation_split=0.1,
              verbose=2)
# Out:
# Epoch 1/25
# 352/352 - 65s - loss: 1.6177 - accuracy: 0.4036 - val_loss: 1.3488 - val_accuracy: 0.5216 - 65s/epoch - 185ms/step
# Epoch 2/25
# 352/352 - 65s - loss: 1.2262 - accuracy: 0.5632 - val_loss: 1.0104 - val_accuracy: 0.6414 - 65s/epoch - 184ms/step
# Epoch 3/25
# 352/352 - 65s - loss: 1.0268 - accuracy: 0.6374 - val_loss: 0.9154 - val_accuracy: 0.6772 - 65s/epoch - 184ms/step
# Epoch 4/25
# 352/352 - 68s - loss: 0.9119 - accuracy: 0.6806 - val_loss: 0.7894 - val_accuracy: 0.7252 - 68s/epoch - 192ms/step
# Epoch 5/25
# 352/352 - 67s - loss: 0.8304 - accuracy: 0.7104 - val_loss: 0.7234 - val_accuracy: 0.7478 - 67s/epoch - 190ms/step
# Epoch 6/25
# 352/352 - 67s - loss: 0.7701 - accuracy: 0.7287 - val_loss: 0.6924 - val_accuracy: 0.7558 - 67s/epoch - 189ms/step
# Epoch 7/25
# 352/352 - 67s - loss: 0.7156 - accuracy: 0.7485 - val_loss: 0.6457 - val_accuracy: 0.7814 - 67s/epoch - 189ms/step
# Epoch 8/25
# 352/352 - 64s - loss: 0.6683 - accuracy: 0.7648 - val_loss: 0.6808 - val_accuracy: 0.7676 - 64s/epoch - 182ms/step
# Epoch 9/25
# 352/352 - 69s - loss: 0.6328 - accuracy: 0.7791 - val_loss: 0.6221 - val_accuracy: 0.7906 - 69s/epoch - 195ms/step
# Epoch 10/25
# 352/352 - 70s - loss: 0.6020 - accuracy: 0.7883 - val_loss: 0.6335 - val_accuracy: 0.7840 - 70s/epoch - 198ms/step
# Epoch 11/25
# 352/352 - 65s - loss: 0.5683 - accuracy: 0.8001 - val_loss: 0.6074 - val_accuracy: 0.7962 - 65s/epoch - 185ms/step
# Epoch 12/25
# 352/352 - 66s - loss: 0.5510 - accuracy: 0.8063 - val_loss: 0.5947 - val_accuracy: 0.8068 - 66s/epoch - 186ms/step
# Epoch 13/25
# 352/352 - 65s - loss: 0.5164 - accuracy: 0.8166 - val_loss: 0.5919 - val_accuracy: 0.8026 - 65s/epoch - 184ms/step
# Epoch 14/25
# 352/352 - 65s - loss: 0.4983 - accuracy: 0.8230 - val_loss: 0.5928 - val_accuracy: 0.8026 - 65s/epoch - 185ms/step
# Epoch 15/25
# 352/352 - 65s - loss: 0.4823 - accuracy: 0.8273 - val_loss: 0.5882 - val_accuracy: 0.8102 - 65s/epoch - 185ms/step
# Epoch 16/25
# 352/352 - 65s - loss: 0.4552 - accuracy: 0.8390 - val_loss: 0.6063 - val_accuracy: 0.7976 - 65s/epoch - 184ms/step
# Epoch 17/25
# 352/352 - 65s - loss: 0.4392 - accuracy: 0.8439 - val_loss: 0.5930 - val_accuracy: 0.8062 - 65s/epoch - 184ms/step
# Epoch 18/25
# 352/352 - 65s - loss: 0.4283 - accuracy: 0.8486 - val_loss: 0.5996 - val_accuracy: 0.8054 - 65s/epoch - 184ms/step
# Epoch 19/25
# 352/352 - 65s - loss: 0.4109 - accuracy: 0.8545 - val_loss: 0.6102 - val_accuracy: 0.8056 - 65s/epoch - 184ms/step
# Epoch 20/25
# 352/352 - 65s - loss: 0.3971 - accuracy: 0.8595 - val_loss: 0.6145 - val_accuracy: 0.8040 - 65s/epoch - 184ms/step
# Epoch 21/25
# 352/352 - 65s - loss: 0.3866 - accuracy: 0.8618 - val_loss: 0.5926 - val_accuracy: 0.8108 - 65s/epoch - 184ms/step
# Epoch 22/25
# 352/352 - 65s - loss: 0.3806 - accuracy: 0.8652 - val_loss: 0.6087 - val_accuracy: 0.8126 - 65s/epoch - 184ms/step
# Epoch 23/25
# 352/352 - 65s - loss: 0.3619 - accuracy: 0.8698 - val_loss: 0.5985 - val_accuracy: 0.8122 - 65s/epoch - 184ms/step
# Epoch 24/25
# 352/352 - 65s - loss: 0.3524 - accuracy: 0.8745 - val_loss: 0.6229 - val_accuracy: 0.8120 - 65s/epoch - 184ms/step
# Epoch 25/25
# 352/352 - 65s - loss: 0.3455 - accuracy: 0.8762 - val_loss: 0.6048 - val_accuracy: 0.8120 - 65s/epoch - 184ms/step

# %% [markdown]
# ## Оцениваем качетсво обучения сети

# %%
# Оцениваем качество обучения модели на тестовых данных
scores = model.evaluate(x_test, y_test, verbose=1)
# Out:
# 313/313 [==============================] - 4s 12ms/step - loss: 0.6529 - accuracy: 0.7960

# %%
print("Доля верных ответов на тестовых данных, в процентах:", round(scores[1] * 100, 4))
# Out:
# Доля верных ответов на тестовых данных, в процентах: 79.6

# %%
plt.plot(history.history['accuracy'],
         label='Доля верных ответов на обучающем наборе')
plt.plot(history.history['val_accuracy'],
         label='Доля верных ответов на проверочном наборе')
plt.xlabel('Эпоха обучения')
plt.ylabel('Доля верных ответов')
plt.legend()
plt.show()

# %%
plt.plot(history.history['loss'],
         label='Ошибка на обучающем наборе')
plt.plot(history.history['val_loss'],
         label='Ошибка на проверочном наборе')
plt.xlabel('Эпоха обучения')
plt.ylabel('Ошибка')
plt.legend()
plt.show()

# %% [markdown]
# ## Сохраняем обученную нейронную сеть

# %%
model.save("cifar10_model.h5")
# Out:
# g:\Python\lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# Сохраняем модель на локальный компьютер

# %% [markdown]
# ## Применяем сеть для распознавания объектов на изображениях

# %% [markdown]
# **Просмотр изображения из набора данных для тестирования**

# %%
index=99
plt.imshow(X_test[index])
plt.show()

# %% [markdown]
# **Преобразование тестового изображения**

# %%
x = x_test[index]
x = np.expand_dims(x, axis=0)

# %% [markdown]
# **Запуск распознавания**

# %%
prediction = model.predict(x)
# Out:
# 1/1 [==============================] - 0s 137ms/step

# %% [markdown]
# **Печатаем результаты распознавания**

# %%
print(prediction)
# Out:
# [[2.5413991e-03 3.2517160e-06 7.5762182e-02 1.9546786e-01 7.5747021e-02
#   1.2176004e-01 1.1213115e-02 5.1722121e-01 1.2117517e-04 1.6284082e-04]]

# %% [markdown]
# **Преобразуем результаты из формата one hot encoding**

# %%
prediction = np.argmax(prediction)
print(classes[prediction])
# Out:
# лошадь

# %% [markdown]
# **Печатаем правильный ответ**

# %%
print(classes[Y_test[index][0]])
# Out:
# лошадь

# %% [markdown]
# ## Распознаем дополнительные изображение

# %% [markdown]
# **Смотрим загруженную картинку**

# %%
os.listdir('data')
# Out:
# ['cat.jpg', 'horse.jpg', 'plane.jpg', 'ship.jpg']

# %%
images = ['data/'+img for img in os.listdir('data')]
for img_path in images:
    img = image.load_img(img_path, target_size=(32, 32))
    plt.imshow(img)
    plt.show()
    x = image.img_to_array(img)
    x /= 255
    x = np.expand_dims(x, axis=0)
    prediction = model.predict(x)
    prediction = np.argmax(prediction)
    print(classes[prediction])
# Out:
# 1/1 [==============================] - 0s 27ms/step
# кот
# 1/1 [==============================] - 0s 24ms/step
# лягушка
# 1/1 [==============================] - 0s 28ms/step
# лошадь
# 1/1 [==============================] - 0s 24ms/step
# самолет
# 1/1 [==============================] - 0s 23ms/step
# корабль
